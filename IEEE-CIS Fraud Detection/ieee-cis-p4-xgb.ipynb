# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/ieee-fraud-detection/train_identity.csv
# /kaggle/input/ieee-fraud-detection/train_transaction.csv
# /kaggle/input/ieee-fraud-detection/test_transaction.csv
# /kaggle/input/ieee-fraud-detection/test_identity.csv
# /kaggle/input/ieee-fraud-detection/sample_submission.csv
# /kaggle/input/ieee-cis-12nd-solution-part-1/X_test2.pkl
# /kaggle/input/ieee-cis-12nd-solution-part-1/X_train2.pkl
# /kaggle/input/ieee-cis-12nd-solution-part-1/custom.css
# /kaggle/input/ieee-cis-12nd-solution-part-1/__results__.html
# /kaggle/input/ieee-cis-12nd-solution-part-1/__output__.json
# /kaggle/input/ieee-cis-12nd-solution-part-1/__notebook__.ipynb
# /kaggle/input/ieee-cis-12nd-solution-part-1/y_train2.pkl

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
from sklearn.metrics import roc_auc_score
import sqlite3
import xgboost as xgb
import datetime
from sklearn.linear_model import LogisticRegression
from scipy.stats import pearsonr
import gc
from sklearn.model_selection import TimeSeriesSplit
import hashlib

# %%
import os
__print__ = print
def print(string):
    __print__(string)
    os.system(f'echo \"{string}\"')

# %%
X_train = pd.read_pickle('../input/ieee-cis-12nd-solution-part-1/X_train2.pkl')
X_test = pd.read_pickle('../input/ieee-cis-12nd-solution-part-1/X_test2.pkl')
y_train = pd.read_pickle('../input/ieee-cis-12nd-solution-part-1/y_train2.pkl')
y_train = y_train.isFraud

# %%
cat = ['uid1','id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29',
            'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType', 'ProductCD', 'card4', 'card6', 'M4','P_emaildomain',
            'R_emaildomain', 'card1', 'card2', 'card3',  'card5', 'addr1', 'addr2', 'M1', 'M2', 'M3', 'M5', 'M6', 'M7', 'M8', 'M9','hour','dow','device_name', 'OS_id_30',  'browser_id_31','ProductID','DeviceInfo__P_emaildomain', 
        'card1__card5', 
        'card2__id_20',
        'card5__P_emaildomain', 
        'addr1__card1',
        'addr1__addr2',
        'card1__card2',
        'card2__addr1',
        'card1__P_emaildomain',
        'card2__P_emaildomain',
        'addr1__P_emaildomain',
        'DeviceInfo__id_31',
        'DeviceInfo__id_20',
        'DeviceType__id_31',
        'DeviceType__id_20',
        'DeviceType__P_emaildomain',
        'card1__M4',
        'card2__M4',
        'addr1__M4',
        'P_emaildomain__M4',
       'uid1__ProductID',
       'uid1__DeviceInfo']

# %%
cat = set(cat) & set(X_train.columns)

# %%
for column in cat:
    train_set = set(X_train[column])
    test_set = set(X_test[column])
    tt = train_set.intersection(test_set)
    print('----------------------------------------')
    print(column)
    print(f'train:{len(tt)/len(train_set)}')
    print(f'test:{len(tt)/len(test_set)}')
    X_train[column] = X_train[column].map(lambda x: -999 if x not in tt else x)
    X_test[column] = X_test[column].map(lambda x: -999 if x not in tt else x)
# Out:
# ----------------------------------------
# card5
# train:0.7
# test:0.8155339805825242
# ----------------------------------------
# addr1__M4
# train:0.6373983739837399
# test:0.6962699822380106
# ----------------------------------------
# M7
# train:1.0
# test:1.0
# ----------------------------------------
# addr1__addr2
# train:0.5136986301369864
# test:0.569620253164557
# ----------------------------------------
# id_33
# train:0.7279693486590039
# test:0.4859335038363171
# ----------------------------------------
# dow
# train:1.0
# test:1.0
# ----------------------------------------
# card1__card2
# train:0.6867254199944919
# test:0.700765825897562
# ----------------------------------------
# addr1__P_emaildomain
# train:0.7479224376731302
# test:0.7792207792207793
# ----------------------------------------
# card5__P_emaildomain
# train:0.7474226804123711
# test:0.8245329000812348
# ----------------------------------------
# addr1
# train:0.5525525525525525
# test:0.6279863481228669
# ----------------------------------------
# P_emaildomain__M4
# train:0.9444444444444444
# test:0.966824644549763
# ----------------------------------------
# DeviceType__P_emaildomain
# train:0.9943502824858758
# test:0.9887640449438202
# ----------------------------------------
# R_emaildomain
# train:1.0
# test:1.0
# ----------------------------------------
# card1__P_emaildomain
# train:0.5412019042800303
# test:0.5949936788874842
# ----------------------------------------
# DeviceInfo__P_emaildomain
# train:0.40294840294840295
# test:0.3663859769719883
# ----------------------------------------
# DeviceInfo__id_31
# train:0.13367799113737075
# test:0.1395259202158412
# ----------------------------------------
# P_emaildomain
# train:1.0
# test:0.9836065573770492
# ----------------------------------------
# id_14
# train:0.9615384615384616
# test:0.8928571428571429
# ----------------------------------------
# hour
# train:1.0
# test:1.0
# ----------------------------------------
# ProductID
# train:0.2539071666588445
# test:0.3730777187780153
# ----------------------------------------
# card1__M4
# train:0.6411827270793449
# test:0.6816680989642228
# ----------------------------------------
# id_19
# train:0.8738049713193117
# test:0.9085487077534792
# ----------------------------------------
# DeviceType__id_31
# train:0.7254901960784313
# test:0.6894409937888198
# ----------------------------------------
# uid1
# train:0.12073629998472034
# test:0.13567933094626056
# ----------------------------------------
# id_13
# train:0.4909090909090909
# test:0.9642857142857143
# ----------------------------------------
# M4
# train:1.0
# test:1.0
# ----------------------------------------
# card2__id_20
# train:0.6699238396321311
# test:0.6714676652743771
# ----------------------------------------
# uid1__DeviceInfo
# train:0.1028989375475554
# test:0.1150085488352212
# ----------------------------------------
# M2
# train:1.0
# test:1.0
# ----------------------------------------
# M6
# train:1.0
# test:1.0
# ----------------------------------------
# uid1__ProductID
# train:0.04352361041676135
# test:0.051496664668066586
# ----------------------------------------
# card2__addr1
# train:0.7194469805660624
# test:0.7564454196379594
# ----------------------------------------
# card2
# train:0.9920159680638723
# test:0.9979919678714859
# ----------------------------------------
# card1__card5
# train:0.6877796901893287
# test:0.699922931408954
# ----------------------------------------
# card6
# train:0.8
# test:1.0
# ----------------------------------------
# M3
# train:1.0
# test:1.0
# ----------------------------------------
# id_18
# train:0.8947368421052632
# test:0.9444444444444444
# ----------------------------------------
# device_name
# train:0.8333333333333334
# test:0.8823529411764706
# ----------------------------------------
# M5
# train:1.0
# test:1.0
# ----------------------------------------
# card2__P_emaildomain
# train:0.7593962710861202
# test:0.8160279853712832
# ----------------------------------------
# DeviceInfo__id_20
# train:0.3211884623725873
# test:0.25567544238239104
# ----------------------------------------
# id_30
# train:0.9868421052631579
# test:0.8620689655172413
# ----------------------------------------
# id_20
# train:0.7189873417721518
# test:0.6498855835240275
# ----------------------------------------
# addr1__card1
# train:0.5559863911542503
# test:0.5907604795194173
# ----------------------------------------
# DeviceType__id_20
# train:0.7169179229480737
# test:0.6445783132530121
# ----------------------------------------
# card1
# train:0.7161514055928576
# test:0.7328601630927213
# ----------------------------------------
# card2__M4
# train:0.9207073588134627
# test:0.9516509433962265
# ----------------------------------------
# id_31
# train:0.7175572519083969
# test:0.6911764705882353

# %%
kf=KFold(n_splits = 5)
resu1 = 0
impor1 = 0
y_pred = 0
stack_train = np.zeros([X_train.shape[0],])
for train_index, test_index in kf.split(X_train, y_train):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    clf = xgb.XGBClassifier(n_estimators=100000, max_depth=11, learning_rate=0.01,random_state=0, subsample=0.8,
                                 colsample_bytree=0.6,min_child_weight = 3,reg_alpha=1,reg_lambda = 0.01,n_jobs=-1,tree_method='gpu_hist')
    clf.fit(X_train2,y_train2,eval_set = [(X_train2,y_train2),(X_test2,y_test2)], eval_metric = 'auc',early_stopping_rounds=500,verbose=30)
    del X_train2,y_train2
    temp_predict = clf.predict_proba(X_test2)[:,1]
    stack_train[test_index] = temp_predict
    y_pred += clf.predict_proba(X_test)[:,1]/5
    roc = roc_auc_score(y_test2, temp_predict)
    print(roc)
    resu1 += roc/5
    impor1 += clf.feature_importances_/5
    del X_test2,y_test2
    gc.collect()
print(f'End:{resu1}')
# Out:
# [0]	validation_0-auc:0.873458	validation_1-auc:0.842863
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 500 rounds.
# [30]	validation_0-auc:0.91136	validation_1-auc:0.87368
# [60]	validation_0-auc:0.917935	validation_1-auc:0.87872
# [90]	validation_0-auc:0.925352	validation_1-auc:0.882396
# [120]	validation_0-auc:0.933237	validation_1-auc:0.888097
# [150]	validation_0-auc:0.940295	validation_1-auc:0.892513
# [180]	validation_0-auc:0.947577	validation_1-auc:0.897253
# [210]	validation_0-auc:0.954542	validation_1-auc:0.902287
# [240]	validation_0-auc:0.962088	validation_1-auc:0.906744
# [270]	validation_0-auc:0.967492	validation_1-auc:0.910183
# [300]	validation_0-auc:0.971451	validation_1-auc:0.912727
# [330]	validation_0-auc:0.974951	validation_1-auc:0.915145
# [360]	validation_0-auc:0.978312	validation_1-auc:0.917239
# [390]	validation_0-auc:0.98113	validation_1-auc:0.91931
# [420]	validation_0-auc:0.98363	validation_1-auc:0.920736
# [450]	validation_0-auc:0.985688	validation_1-auc:0.922168
# [480]	validation_0-auc:0.987313	validation_1-auc:0.923615
# [510]	validation_0-auc:0.988851	validation_1-auc:0.925044
# [540]	validation_0-auc:0.990051	validation_1-auc:0.926171
# [570]	validation_0-auc:0.99111	validation_1-auc:0.927364
# [600]	validation_0-auc:0.991959	validation_1-auc:0.92845
# [630]	validation_0-auc:0.992719	validation_1-auc:0.929388
# [660]	validation_0-auc:0.993371	validation_1-auc:0.930467
# [690]	validation_0-auc:0.993959	validation_1-auc:0.931286
# [720]	validation_0-auc:0.99443	validation_1-auc:0.93205
# [750]	validation_0-auc:0.994824	validation_1-auc:0.932907
# [780]	validation_0-auc:0.995212	validation_1-auc:0.933698
# [810]	validation_0-auc:0.995555	validation_1-auc:0.934139
# [840]	validation_0-auc:0.995904	validation_1-auc:0.934583
# [870]	validation_0-auc:0.996133	validation_1-auc:0.935169
# [900]	validation_0-auc:0.996411	validation_1-auc:0.935529
# [930]	validation_0-auc:0.996709	validation_1-auc:0.936008
# [960]	validation_0-auc:0.996945	validation_1-auc:0.936483
# [990]	validation_0-auc:0.997177	validation_1-auc:0.936864
# [1020]	validation_0-auc:0.997359	validation_1-auc:0.937107
# [1050]	validation_0-auc:0.997523	validation_1-auc:0.937418
# [1080]	validation_0-auc:0.997679	validation_1-auc:0.93773
# [1110]	validation_0-auc:0.997849	validation_1-auc:0.937948
# [1140]	validation_0-auc:0.997988	validation_1-auc:0.938339
# [1170]	validation_0-auc:0.998119	validation_1-auc:0.938567
# [1200]	validation_0-auc:0.998245	validation_1-auc:0.938663
# [1230]	validation_0-auc:0.998365	validation_1-auc:0.93894
# [1260]	validation_0-auc:0.998463	validation_1-auc:0.939079
# [1290]	validation_0-auc:0.998555	validation_1-auc:0.939184
# [1320]	validation_0-auc:0.998646	validation_1-auc:0.939312
# [1350]	validation_0-auc:0.998742	validation_1-auc:0.93932
# [1380]	validation_0-auc:0.998823	validation_1-auc:0.939581
# [1410]	validation_0-auc:0.9989	validation_1-auc:0.939646
# [1440]	validation_0-auc:0.99897	validation_1-auc:0.939796
# [1470]	validation_0-auc:0.999042	validation_1-auc:0.939898
# [1500]	validation_0-auc:0.999099	validation_1-auc:0.939965
# [1530]	validation_0-auc:0.99915	validation_1-auc:0.94006
# [1560]	validation_0-auc:0.999203	validation_1-auc:0.940171
# [1590]	validation_0-auc:0.999265	validation_1-auc:0.940291
# [1620]	validation_0-auc:0.999312	validation_1-auc:0.940373
# [1650]	validation_0-auc:0.999359	validation_1-auc:0.940504
# [1680]	validation_0-auc:0.999405	validation_1-auc:0.940578
# [1710]	validation_0-auc:0.999438	validation_1-auc:0.94059
# [1740]	validation_0-auc:0.999473	validation_1-auc:0.940628
# [1770]	validation_0-auc:0.999504	validation_1-auc:0.940737
# [1800]	validation_0-auc:0.999533	validation_1-auc:0.9408
# [1830]	validation_0-auc:0.999564	validation_1-auc:0.940809
# [1860]	validation_0-auc:0.999586	validation_1-auc:0.940855
# [1890]	validation_0-auc:0.999613	validation_1-auc:0.940964
# [1920]	validation_0-auc:0.999641	validation_1-auc:0.941066
# [1950]	validation_0-auc:0.999667	validation_1-auc:0.94108
# [1980]	validation_0-auc:0.999689	validation_1-auc:0.941113
# [2010]	validation_0-auc:0.99971	validation_1-auc:0.94119
# [2040]	validation_0-auc:0.999733	validation_1-auc:0.941166
# [2070]	validation_0-auc:0.99975	validation_1-auc:0.941171
# [2100]	validation_0-auc:0.999766	validation_1-auc:0.941189
# [2130]	validation_0-auc:0.99978	validation_1-auc:0.941164
# [2160]	validation_0-auc:0.999797	validation_1-auc:0.94112
# [2190]	validation_0-auc:0.999809	validation_1-auc:0.941127
# [2220]	validation_0-auc:0.999824	validation_1-auc:0.941151
# [2250]	validation_0-auc:0.999835	validation_1-auc:0.941192
# [2280]	validation_0-auc:0.999846	validation_1-auc:0.941213
# [2310]	validation_0-auc:0.999857	validation_1-auc:0.941285
# [2340]	validation_0-auc:0.999866	validation_1-auc:0.941316
# [2370]	validation_0-auc:0.999874	validation_1-auc:0.941362
# [2400]	validation_0-auc:0.999883	validation_1-auc:0.941403
# [2430]	validation_0-auc:0.999892	validation_1-auc:0.94144
# [2460]	validation_0-auc:0.999897	validation_1-auc:0.941433
# [2490]	validation_0-auc:0.999905	validation_1-auc:0.941406
# [2520]	validation_0-auc:0.999913	validation_1-auc:0.941403
# [2550]	validation_0-auc:0.99992	validation_1-auc:0.941385
# [2580]	validation_0-auc:0.999925	validation_1-auc:0.941402
# [2610]	validation_0-auc:0.999931	validation_1-auc:0.941449
# [2640]	validation_0-auc:0.999935	validation_1-auc:0.941468
# [2670]	validation_0-auc:0.999939	validation_1-auc:0.941499
# [2700]	validation_0-auc:0.999944	validation_1-auc:0.941547
# [2730]	validation_0-auc:0.999947	validation_1-auc:0.941558
# [2760]	validation_0-auc:0.999951	validation_1-auc:0.941607
# [2790]	validation_0-auc:0.999955	validation_1-auc:0.941642
# [2820]	validation_0-auc:0.999958	validation_1-auc:0.941655
# [2850]	validation_0-auc:0.999961	validation_1-auc:0.941611
# [2880]	validation_0-auc:0.999964	validation_1-auc:0.941582
# [2910]	validation_0-auc:0.999967	validation_1-auc:0.941608
# [2940]	validation_0-auc:0.999969	validation_1-auc:0.941589
# [2970]	validation_0-auc:0.999972	validation_1-auc:0.941599
# [3000]	validation_0-auc:0.999974	validation_1-auc:0.94162
# [3030]	validation_0-auc:0.999976	validation_1-auc:0.941623
# [3060]	validation_0-auc:0.999978	validation_1-auc:0.941644
# [3090]	validation_0-auc:0.99998	validation_1-auc:0.941639
# [3120]	validation_0-auc:0.999982	validation_1-auc:0.941658
# [3150]	validation_0-auc:0.999983	validation_1-auc:0.941661
# [3180]	validation_0-auc:0.999985	validation_1-auc:0.94172
# [3210]	validation_0-auc:0.999986	validation_1-auc:0.941643
# [3240]	validation_0-auc:0.999988	validation_1-auc:0.941645
# [3270]	validation_0-auc:0.999989	validation_1-auc:0.941656
# [3300]	validation_0-auc:0.99999	validation_1-auc:0.94171
# [3330]	validation_0-auc:0.99999	validation_1-auc:0.94175
# [3360]	validation_0-auc:0.999991	validation_1-auc:0.941779
# [3390]	validation_0-auc:0.999992	validation_1-auc:0.941846
# [3420]	validation_0-auc:0.999993	validation_1-auc:0.941882
# [3450]	validation_0-auc:0.999993	validation_1-auc:0.941891
# [3480]	validation_0-auc:0.999994	validation_1-auc:0.941874
# [3510]	validation_0-auc:0.999994	validation_1-auc:0.941828
# [3540]	validation_0-auc:0.999995	validation_1-auc:0.941815
# [3570]	validation_0-auc:0.999995	validation_1-auc:0.941835
# [3600]	validation_0-auc:0.999996	validation_1-auc:0.941804
# [3630]	validation_0-auc:0.999996	validation_1-auc:0.941787
# [3660]	validation_0-auc:0.999996	validation_1-auc:0.941795
# [3690]	validation_0-auc:0.999997	validation_1-auc:0.941781
# [3720]	validation_0-auc:0.999997	validation_1-auc:0.941771
# [3750]	validation_0-auc:0.999997	validation_1-auc:0.941803
# [3780]	validation_0-auc:0.999997	validation_1-auc:0.941802
# [3810]	validation_0-auc:0.999998	validation_1-auc:0.941811
# [3840]	validation_0-auc:0.999998	validation_1-auc:0.941808
# [3870]	validation_0-auc:0.999998	validation_1-auc:0.941824
# [3900]	validation_0-auc:0.999998	validation_1-auc:0.941816
# [3930]	validation_0-auc:0.999998	validation_1-auc:0.94182
# [3960]	validation_0-auc:0.999998	validation_1-auc:0.941839
# Stopping. Best iteration:
# [3475]	validation_0-auc:0.999994	validation_1-auc:0.941907
#
# 0.9419068979108101
# [0]	validation_0-auc:0.871519	validation_1-auc:0.844143
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 500 rounds.
# [30]	validation_0-auc:0.910197	validation_1-auc:0.892978
# [60]	validation_0-auc:0.916545	validation_1-auc:0.896897
# [90]	validation_0-auc:0.923097	validation_1-auc:0.901121
# [120]	validation_0-auc:0.92805	validation_1-auc:0.904058
# [150]	validation_0-auc:0.934118	validation_1-auc:0.908125
# [180]	validation_0-auc:0.939794	validation_1-auc:0.911437
# [210]	validation_0-auc:0.946567	validation_1-auc:0.915984
# [240]	validation_0-auc:0.953767	validation_1-auc:0.920784
# [270]	validation_0-auc:0.961525	validation_1-auc:0.925893
# [300]	validation_0-auc:0.967104	validation_1-auc:0.93005
# [330]	validation_0-auc:0.971697	validation_1-auc:0.933478
# [360]	validation_0-auc:0.975605	validation_1-auc:0.936306
# [390]	validation_0-auc:0.979	validation_1-auc:0.939165
# [420]	validation_0-auc:0.981825	validation_1-auc:0.941579
# [450]	validation_0-auc:0.984095	validation_1-auc:0.943507
# [480]	validation_0-auc:0.985886	validation_1-auc:0.945249
# [510]	validation_0-auc:0.987577	validation_1-auc:0.946954
# [540]	validation_0-auc:0.988988	validation_1-auc:0.948237
# [570]	validation_0-auc:0.990127	validation_1-auc:0.949417
# [600]	validation_0-auc:0.991079	validation_1-auc:0.950365
# [630]	validation_0-auc:0.99189	validation_1-auc:0.951335
# [660]	validation_0-auc:0.992607	validation_1-auc:0.952122
# [690]	validation_0-auc:0.993311	validation_1-auc:0.952893
# [720]	validation_0-auc:0.993876	validation_1-auc:0.953384
# [750]	validation_0-auc:0.994308	validation_1-auc:0.953742
# [780]	validation_0-auc:0.994733	validation_1-auc:0.95421
# [810]	validation_0-auc:0.995058	validation_1-auc:0.954603
# [840]	validation_0-auc:0.995376	validation_1-auc:0.954921
# [870]	validation_0-auc:0.995686	validation_1-auc:0.955228
# [900]	validation_0-auc:0.996017	validation_1-auc:0.955378
# [930]	validation_0-auc:0.996297	validation_1-auc:0.955591
# [960]	validation_0-auc:0.996574	validation_1-auc:0.955837
# [990]	validation_0-auc:0.996831	validation_1-auc:0.956068
# [1020]	validation_0-auc:0.997052	validation_1-auc:0.956307
# [1050]	validation_0-auc:0.997205	validation_1-auc:0.956424
# [1080]	validation_0-auc:0.997376	validation_1-auc:0.956607
# [1110]	validation_0-auc:0.997572	validation_1-auc:0.956686
# [1140]	validation_0-auc:0.997725	validation_1-auc:0.956819
# [1170]	validation_0-auc:0.997874	validation_1-auc:0.956964
# [1200]	validation_0-auc:0.99801	validation_1-auc:0.957065
# [1230]	validation_0-auc:0.998137	validation_1-auc:0.957164
# [1260]	validation_0-auc:0.998257	validation_1-auc:0.957237
# [1290]	validation_0-auc:0.998388	validation_1-auc:0.957223
# [1320]	validation_0-auc:0.998475	validation_1-auc:0.957338
# [1350]	validation_0-auc:0.998568	validation_1-auc:0.957422
# [1380]	validation_0-auc:0.998652	validation_1-auc:0.957483
# [1410]	validation_0-auc:0.998734	validation_1-auc:0.957491
# [1440]	validation_0-auc:0.998823	validation_1-auc:0.957573
# [1470]	validation_0-auc:0.998905	validation_1-auc:0.957597
# [1500]	validation_0-auc:0.998972	validation_1-auc:0.957669
# [1530]	validation_0-auc:0.999045	validation_1-auc:0.957761
# [1560]	validation_0-auc:0.999098	validation_1-auc:0.957762
# [1590]	validation_0-auc:0.999156	validation_1-auc:0.957803
# [1620]	validation_0-auc:0.999217	validation_1-auc:0.957878
# [1650]	validation_0-auc:0.999272	validation_1-auc:0.957923
# [1680]	validation_0-auc:0.999324	validation_1-auc:0.957904
# [1710]	validation_0-auc:0.999368	validation_1-auc:0.957938
# [1740]	validation_0-auc:0.999412	validation_1-auc:0.957908
# [1770]	validation_0-auc:0.999449	validation_1-auc:0.957906
# [1800]	validation_0-auc:0.999489	validation_1-auc:0.957963
# [1830]	validation_0-auc:0.999523	validation_1-auc:0.95793
# [1860]	validation_0-auc:0.999555	validation_1-auc:0.95799
# [1890]	validation_0-auc:0.999596	validation_1-auc:0.958015
# [1920]	validation_0-auc:0.999626	validation_1-auc:0.958022
# [1950]	validation_0-auc:0.999647	validation_1-auc:0.958054
# [1980]	validation_0-auc:0.999671	validation_1-auc:0.958052
# [2010]	validation_0-auc:0.999691	validation_1-auc:0.958086
# [2040]	validation_0-auc:0.999711	validation_1-auc:0.958129
# [2070]	validation_0-auc:0.999731	validation_1-auc:0.958135
# [2100]	validation_0-auc:0.999751	validation_1-auc:0.958163
# [2130]	validation_0-auc:0.999767	validation_1-auc:0.958222
# [2160]	validation_0-auc:0.999779	validation_1-auc:0.958196
# [2190]	validation_0-auc:0.999793	validation_1-auc:0.95815
# [2220]	validation_0-auc:0.999806	validation_1-auc:0.958151
# [2250]	validation_0-auc:0.99982	validation_1-auc:0.95813
# [2280]	validation_0-auc:0.999832	validation_1-auc:0.95813
# [2310]	validation_0-auc:0.999843	validation_1-auc:0.958151
# [2340]	validation_0-auc:0.999854	validation_1-auc:0.958133
# [2370]	validation_0-auc:0.999864	validation_1-auc:0.958184
# [2400]	validation_0-auc:0.999872	validation_1-auc:0.958192
# [2430]	validation_0-auc:0.999881	validation_1-auc:0.958237
# [2460]	validation_0-auc:0.999888	validation_1-auc:0.958195
# [2490]	validation_0-auc:0.999896	validation_1-auc:0.958204
# [2520]	validation_0-auc:0.999904	validation_1-auc:0.958268
# [2550]	validation_0-auc:0.99991	validation_1-auc:0.958247
# [2580]	validation_0-auc:0.999917	validation_1-auc:0.958248
# [2610]	validation_0-auc:0.999924	validation_1-auc:0.958198
# [2640]	validation_0-auc:0.99993	validation_1-auc:0.958195
# [2670]	validation_0-auc:0.999935	validation_1-auc:0.958182
# [2700]	validation_0-auc:0.999939	validation_1-auc:0.958219
# [2730]	validation_0-auc:0.999943	validation_1-auc:0.958184
# [2760]	validation_0-auc:0.999947	validation_1-auc:0.958161
# [2790]	validation_0-auc:0.999952	validation_1-auc:0.958166
# [2820]	validation_0-auc:0.999955	validation_1-auc:0.958158
# [2850]	validation_0-auc:0.999959	validation_1-auc:0.958122
# [2880]	validation_0-auc:0.999962	validation_1-auc:0.958082
# [2910]	validation_0-auc:0.999965	validation_1-auc:0.958154
# [2940]	validation_0-auc:0.999968	validation_1-auc:0.958125
# [2970]	validation_0-auc:0.99997	validation_1-auc:0.958113
# [3000]	validation_0-auc:0.999973	validation_1-auc:0.958097
# Stopping. Best iteration:
# [2527]	validation_0-auc:0.999906	validation_1-auc:0.958283
#
# 0.9582827867517749
# [0]	validation_0-auc:0.891178	validation_1-auc:0.862623
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 500 rounds.
# [30]	validation_0-auc:0.915614	validation_1-auc:0.89644
# [60]	validation_0-auc:0.920273	validation_1-auc:0.899038
# [90]	validation_0-auc:0.926923	validation_1-auc:0.903552
# [120]	validation_0-auc:0.934768	validation_1-auc:0.908151
# [150]	validation_0-auc:0.940377	validation_1-auc:0.911702
# [180]	validation_0-auc:0.945167	validation_1-auc:0.915013
# [210]	validation_0-auc:0.951331	validation_1-auc:0.919273
# [240]	validation_0-auc:0.959373	validation_1-auc:0.924889
# [270]	validation_0-auc:0.96632	validation_1-auc:0.929789
# [300]	validation_0-auc:0.971046	validation_1-auc:0.933161
# [330]	validation_0-auc:0.974565	validation_1-auc:0.935974
# [360]	validation_0-auc:0.978104	validation_1-auc:0.93866
# [390]	validation_0-auc:0.98094	validation_1-auc:0.940785
# [420]	validation_0-auc:0.983303	validation_1-auc:0.94228
# [450]	validation_0-auc:0.985431	validation_1-auc:0.943613
# [480]	validation_0-auc:0.987065	validation_1-auc:0.944636
# [510]	validation_0-auc:0.988595	validation_1-auc:0.945653
# [540]	validation_0-auc:0.989719	validation_1-auc:0.946519
# [570]	validation_0-auc:0.990771	validation_1-auc:0.947447
# [600]	validation_0-auc:0.991699	validation_1-auc:0.948162
# [630]	validation_0-auc:0.992451	validation_1-auc:0.948756
# [660]	validation_0-auc:0.993067	validation_1-auc:0.949369
# [690]	validation_0-auc:0.993705	validation_1-auc:0.949836
# [720]	validation_0-auc:0.994244	validation_1-auc:0.950209
# [750]	validation_0-auc:0.994687	validation_1-auc:0.950647
# [780]	validation_0-auc:0.99511	validation_1-auc:0.950998
# [810]	validation_0-auc:0.995439	validation_1-auc:0.951197
# [840]	validation_0-auc:0.995781	validation_1-auc:0.951409
# [870]	validation_0-auc:0.996094	validation_1-auc:0.951641
# [900]	validation_0-auc:0.996395	validation_1-auc:0.951792
# [930]	validation_0-auc:0.99663	validation_1-auc:0.951969
# [960]	validation_0-auc:0.996845	validation_1-auc:0.952158
# [990]	validation_0-auc:0.997078	validation_1-auc:0.952347
# [1020]	validation_0-auc:0.997233	validation_1-auc:0.9524
# [1050]	validation_0-auc:0.997417	validation_1-auc:0.95253
# [1080]	validation_0-auc:0.997577	validation_1-auc:0.952653
# [1110]	validation_0-auc:0.99774	validation_1-auc:0.952648
# [1140]	validation_0-auc:0.997872	validation_1-auc:0.952707
# [1170]	validation_0-auc:0.998024	validation_1-auc:0.952704
# [1200]	validation_0-auc:0.998158	validation_1-auc:0.952753
# [1230]	validation_0-auc:0.998261	validation_1-auc:0.952736
# [1260]	validation_0-auc:0.998362	validation_1-auc:0.952807
# [1290]	validation_0-auc:0.99847	validation_1-auc:0.952852
# [1320]	validation_0-auc:0.998557	validation_1-auc:0.952937
# [1350]	validation_0-auc:0.998641	validation_1-auc:0.953031
# [1380]	validation_0-auc:0.998722	validation_1-auc:0.953008
# [1410]	validation_0-auc:0.9988	validation_1-auc:0.953025
# [1440]	validation_0-auc:0.99888	validation_1-auc:0.953025
# [1470]	validation_0-auc:0.998955	validation_1-auc:0.953023
# [1500]	validation_0-auc:0.999027	validation_1-auc:0.953111
# [1530]	validation_0-auc:0.999102	validation_1-auc:0.95317
# [1560]	validation_0-auc:0.999156	validation_1-auc:0.953265
# [1590]	validation_0-auc:0.999221	validation_1-auc:0.953266
# [1620]	validation_0-auc:0.999283	validation_1-auc:0.953302
# [1650]	validation_0-auc:0.999333	validation_1-auc:0.953332
# [1680]	validation_0-auc:0.999377	validation_1-auc:0.953349
# [1710]	validation_0-auc:0.999412	validation_1-auc:0.953392
# [1740]	validation_0-auc:0.999451	validation_1-auc:0.953423
# [1770]	validation_0-auc:0.999489	validation_1-auc:0.953441
# [1800]	validation_0-auc:0.999523	validation_1-auc:0.953391
# [1830]	validation_0-auc:0.999558	validation_1-auc:0.953418
# [1860]	validation_0-auc:0.999593	validation_1-auc:0.953475
# [1890]	validation_0-auc:0.999625	validation_1-auc:0.953416
# [1920]	validation_0-auc:0.999653	validation_1-auc:0.953436
# [1950]	validation_0-auc:0.999676	validation_1-auc:0.953438
# [1980]	validation_0-auc:0.999698	validation_1-auc:0.953345
# [2010]	validation_0-auc:0.999715	validation_1-auc:0.953328
# [2040]	validation_0-auc:0.999737	validation_1-auc:0.953235
# [2070]	validation_0-auc:0.999757	validation_1-auc:0.953218
# [2100]	validation_0-auc:0.999773	validation_1-auc:0.95316
# [2130]	validation_0-auc:0.999792	validation_1-auc:0.95319
# [2160]	validation_0-auc:0.99981	validation_1-auc:0.953174
# [2190]	validation_0-auc:0.999821	validation_1-auc:0.953204
# [2220]	validation_0-auc:0.999834	validation_1-auc:0.953185
# [2250]	validation_0-auc:0.999845	validation_1-auc:0.953156
# [2280]	validation_0-auc:0.999857	validation_1-auc:0.953133
# [2310]	validation_0-auc:0.999866	validation_1-auc:0.953128
# [2340]	validation_0-auc:0.999876	validation_1-auc:0.953164
# Stopping. Best iteration:
# [1860]	validation_0-auc:0.999593	validation_1-auc:0.953475
#
# 0.9534749353615616
# [0]	validation_0-auc:0.873269	validation_1-auc:0.863411
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 500 rounds.
# [30]	validation_0-auc:0.907756	validation_1-auc:0.904778
# [60]	validation_0-auc:0.913228	validation_1-auc:0.909071
# [90]	validation_0-auc:0.919895	validation_1-auc:0.913443
# [120]	validation_0-auc:0.925815	validation_1-auc:0.917013
# [150]	validation_0-auc:0.933268	validation_1-auc:0.921915
# [180]	validation_0-auc:0.938893	validation_1-auc:0.925772
# [210]	validation_0-auc:0.944361	validation_1-auc:0.929147
# [240]	validation_0-auc:0.954802	validation_1-auc:0.936213
# [270]	validation_0-auc:0.962925	validation_1-auc:0.941245
# [300]	validation_0-auc:0.968364	validation_1-auc:0.94495
# [330]	validation_0-auc:0.972586	validation_1-auc:0.947942
# [360]	validation_0-auc:0.976444	validation_1-auc:0.950623
# [390]	validation_0-auc:0.979802	validation_1-auc:0.952759
# [420]	validation_0-auc:0.982426	validation_1-auc:0.954339
# [450]	validation_0-auc:0.984655	validation_1-auc:0.955869
# [480]	validation_0-auc:0.986462	validation_1-auc:0.957076
# [510]	validation_0-auc:0.987997	validation_1-auc:0.958228
# [540]	validation_0-auc:0.989308	validation_1-auc:0.959276
# [570]	validation_0-auc:0.990352	validation_1-auc:0.960182
# [600]	validation_0-auc:0.991207	validation_1-auc:0.96102
# [630]	validation_0-auc:0.991989	validation_1-auc:0.961782
# [660]	validation_0-auc:0.992629	validation_1-auc:0.96237
# [690]	validation_0-auc:0.993261	validation_1-auc:0.962984
# [720]	validation_0-auc:0.993752	validation_1-auc:0.963478
# [750]	validation_0-auc:0.994188	validation_1-auc:0.96394
# [780]	validation_0-auc:0.994568	validation_1-auc:0.96432
# [810]	validation_0-auc:0.994929	validation_1-auc:0.964653
# [840]	validation_0-auc:0.995277	validation_1-auc:0.964956
# [870]	validation_0-auc:0.995631	validation_1-auc:0.965198
# [900]	validation_0-auc:0.995903	validation_1-auc:0.965414
# [930]	validation_0-auc:0.996157	validation_1-auc:0.965669
# [960]	validation_0-auc:0.996399	validation_1-auc:0.965842
# [990]	validation_0-auc:0.996631	validation_1-auc:0.965992
# [1020]	validation_0-auc:0.996818	validation_1-auc:0.966145
# [1050]	validation_0-auc:0.997036	validation_1-auc:0.966301
# [1080]	validation_0-auc:0.997182	validation_1-auc:0.966442
# [1110]	validation_0-auc:0.997353	validation_1-auc:0.966594
# [1140]	validation_0-auc:0.997524	validation_1-auc:0.966703
# [1170]	validation_0-auc:0.997684	validation_1-auc:0.966826
# [1200]	validation_0-auc:0.99784	validation_1-auc:0.966962
# [1230]	validation_0-auc:0.997977	validation_1-auc:0.967066
# [1260]	validation_0-auc:0.998098	validation_1-auc:0.96717
# [1290]	validation_0-auc:0.998232	validation_1-auc:0.967292
# [1320]	validation_0-auc:0.998333	validation_1-auc:0.967356
# [1350]	validation_0-auc:0.99844	validation_1-auc:0.967424
# [1380]	validation_0-auc:0.998541	validation_1-auc:0.967516
# [1410]	validation_0-auc:0.998647	validation_1-auc:0.967638
# [1440]	validation_0-auc:0.998736	validation_1-auc:0.967718
# [1470]	validation_0-auc:0.998819	validation_1-auc:0.967813
# [1500]	validation_0-auc:0.998884	validation_1-auc:0.967849
# [1530]	validation_0-auc:0.998948	validation_1-auc:0.967866
# [1560]	validation_0-auc:0.99902	validation_1-auc:0.967895
# [1590]	validation_0-auc:0.99908	validation_1-auc:0.967914
# [1620]	validation_0-auc:0.999143	validation_1-auc:0.967918
# [1650]	validation_0-auc:0.999207	validation_1-auc:0.967982
# [1680]	validation_0-auc:0.999259	validation_1-auc:0.967988
# [1710]	validation_0-auc:0.999311	validation_1-auc:0.968012
# [1740]	validation_0-auc:0.999363	validation_1-auc:0.968118
# [1770]	validation_0-auc:0.999412	validation_1-auc:0.968157
# [1800]	validation_0-auc:0.999455	validation_1-auc:0.968165
# [1830]	validation_0-auc:0.999491	validation_1-auc:0.968148
# [1860]	validation_0-auc:0.999525	validation_1-auc:0.968169
# [1890]	validation_0-auc:0.999561	validation_1-auc:0.968185
# [1920]	validation_0-auc:0.999595	validation_1-auc:0.96823
# [1950]	validation_0-auc:0.999624	validation_1-auc:0.968209
# [1980]	validation_0-auc:0.999651	validation_1-auc:0.968243
# [2010]	validation_0-auc:0.999672	validation_1-auc:0.968255
# [2040]	validation_0-auc:0.999696	validation_1-auc:0.968231
# [2070]	validation_0-auc:0.99972	validation_1-auc:0.968246
# [2100]	validation_0-auc:0.999739	validation_1-auc:0.968241
# [2130]	validation_0-auc:0.999762	validation_1-auc:0.968267
# [2160]	validation_0-auc:0.999777	validation_1-auc:0.968246
# [2190]	validation_0-auc:0.999792	validation_1-auc:0.968261
# [2220]	validation_0-auc:0.999808	validation_1-auc:0.968266
# [2250]	validation_0-auc:0.999822	validation_1-auc:0.96829
# [2280]	validation_0-auc:0.999836	validation_1-auc:0.968275
# [2310]	validation_0-auc:0.999848	validation_1-auc:0.968272
# [2340]	validation_0-auc:0.999859	validation_1-auc:0.96824
# [2370]	validation_0-auc:0.999868	validation_1-auc:0.968214
# [2400]	validation_0-auc:0.999877	validation_1-auc:0.968191
# [2430]	validation_0-auc:0.999885	validation_1-auc:0.968146
# [2460]	validation_0-auc:0.999894	validation_1-auc:0.96812
# [2490]	validation_0-auc:0.999902	validation_1-auc:0.968112
# [2520]	validation_0-auc:0.99991	validation_1-auc:0.968095
# [2550]	validation_0-auc:0.999917	validation_1-auc:0.968103
# [2580]	validation_0-auc:0.999924	validation_1-auc:0.968094
# [2610]	validation_0-auc:0.99993	validation_1-auc:0.968119
# [2640]	validation_0-auc:0.999935	validation_1-auc:0.968108
# [2670]	validation_0-auc:0.999939	validation_1-auc:0.968127
# [2700]	validation_0-auc:0.999944	validation_1-auc:0.96816
# [2730]	validation_0-auc:0.999948	validation_1-auc:0.968116
# Stopping. Best iteration:
# [2238]	validation_0-auc:0.999817	validation_1-auc:0.968301
#
# 0.968300742247599
# [0]	validation_0-auc:0.87455	validation_1-auc:0.839322
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 500 rounds.
# [30]	validation_0-auc:0.911564	validation_1-auc:0.8775
# [60]	validation_0-auc:0.91808	validation_1-auc:0.8833
# [90]	validation_0-auc:0.926146	validation_1-auc:0.887359
# [120]	validation_0-auc:0.932641	validation_1-auc:0.891208
# [150]	validation_0-auc:0.939363	validation_1-auc:0.895514
# [180]	validation_0-auc:0.9447	validation_1-auc:0.899261
# [210]	validation_0-auc:0.951203	validation_1-auc:0.904028
# [240]	validation_0-auc:0.958634	validation_1-auc:0.908508
# [270]	validation_0-auc:0.965034	validation_1-auc:0.912907
# [300]	validation_0-auc:0.970133	validation_1-auc:0.916813
# [330]	validation_0-auc:0.974113	validation_1-auc:0.920195
# [360]	validation_0-auc:0.977686	validation_1-auc:0.922965
# [390]	validation_0-auc:0.980563	validation_1-auc:0.925243
# [420]	validation_0-auc:0.983214	validation_1-auc:0.927469
# [450]	validation_0-auc:0.985333	validation_1-auc:0.929026
# [480]	validation_0-auc:0.987063	validation_1-auc:0.930758
# [510]	validation_0-auc:0.98859	validation_1-auc:0.932051
# [540]	validation_0-auc:0.989796	validation_1-auc:0.933325
# [570]	validation_0-auc:0.990851	validation_1-auc:0.934493
# [600]	validation_0-auc:0.991643	validation_1-auc:0.935327
# [630]	validation_0-auc:0.99243	validation_1-auc:0.936303
# [660]	validation_0-auc:0.993116	validation_1-auc:0.937228
# [690]	validation_0-auc:0.993618	validation_1-auc:0.938
# [720]	validation_0-auc:0.994073	validation_1-auc:0.938621
# [750]	validation_0-auc:0.994495	validation_1-auc:0.93922
# [780]	validation_0-auc:0.994864	validation_1-auc:0.939579
# [810]	validation_0-auc:0.99523	validation_1-auc:0.940102
# [840]	validation_0-auc:0.995577	validation_1-auc:0.940647
# [870]	validation_0-auc:0.995913	validation_1-auc:0.940919
# [900]	validation_0-auc:0.996177	validation_1-auc:0.941252
# [930]	validation_0-auc:0.996415	validation_1-auc:0.941438
# [960]	validation_0-auc:0.996599	validation_1-auc:0.941682
# [990]	validation_0-auc:0.996807	validation_1-auc:0.941861
# [1020]	validation_0-auc:0.997028	validation_1-auc:0.94212
# [1050]	validation_0-auc:0.997238	validation_1-auc:0.942352
# [1080]	validation_0-auc:0.997403	validation_1-auc:0.942581
# [1110]	validation_0-auc:0.997569	validation_1-auc:0.942704
# [1140]	validation_0-auc:0.997737	validation_1-auc:0.942945
# [1170]	validation_0-auc:0.997904	validation_1-auc:0.943063
# [1200]	validation_0-auc:0.998062	validation_1-auc:0.943248
# [1230]	validation_0-auc:0.99817	validation_1-auc:0.943315
# [1260]	validation_0-auc:0.998279	validation_1-auc:0.943466
# [1290]	validation_0-auc:0.998378	validation_1-auc:0.943513
# [1320]	validation_0-auc:0.998488	validation_1-auc:0.943656
# [1350]	validation_0-auc:0.998591	validation_1-auc:0.943882
# [1380]	validation_0-auc:0.998679	validation_1-auc:0.943921
# [1410]	validation_0-auc:0.99877	validation_1-auc:0.944026
# [1440]	validation_0-auc:0.99885	validation_1-auc:0.944209
# [1470]	validation_0-auc:0.998934	validation_1-auc:0.944245
# [1500]	validation_0-auc:0.998999	validation_1-auc:0.944334
# [1530]	validation_0-auc:0.999061	validation_1-auc:0.944382
# [1560]	validation_0-auc:0.999114	validation_1-auc:0.944491
# [1590]	validation_0-auc:0.999171	validation_1-auc:0.94448
# [1620]	validation_0-auc:0.999232	validation_1-auc:0.944503
# [1650]	validation_0-auc:0.999286	validation_1-auc:0.94464
# [1680]	validation_0-auc:0.999343	validation_1-auc:0.944657
# [1710]	validation_0-auc:0.999392	validation_1-auc:0.944778
# [1740]	validation_0-auc:0.999426	validation_1-auc:0.944833
# [1770]	validation_0-auc:0.999468	validation_1-auc:0.94483
# [1800]	validation_0-auc:0.999514	validation_1-auc:0.944915
# [1830]	validation_0-auc:0.999544	validation_1-auc:0.944976
# [1860]	validation_0-auc:0.999571	validation_1-auc:0.944957
# [1890]	validation_0-auc:0.999609	validation_1-auc:0.944992
# [1920]	validation_0-auc:0.999638	validation_1-auc:0.945065
# [1950]	validation_0-auc:0.999661	validation_1-auc:0.945175
# [1980]	validation_0-auc:0.999687	validation_1-auc:0.945231
# [2010]	validation_0-auc:0.999705	validation_1-auc:0.945228
# [2040]	validation_0-auc:0.999725	validation_1-auc:0.945238
# [2070]	validation_0-auc:0.999742	validation_1-auc:0.945271
# [2100]	validation_0-auc:0.999756	validation_1-auc:0.945259
# [2130]	validation_0-auc:0.999775	validation_1-auc:0.945331
# [2160]	validation_0-auc:0.999791	validation_1-auc:0.94539
# [2190]	validation_0-auc:0.999807	validation_1-auc:0.94534
# [2220]	validation_0-auc:0.999819	validation_1-auc:0.94537
# [2250]	validation_0-auc:0.999831	validation_1-auc:0.945402
# [2280]	validation_0-auc:0.999845	validation_1-auc:0.945488
# [2310]	validation_0-auc:0.999856	validation_1-auc:0.945482
# [2340]	validation_0-auc:0.999866	validation_1-auc:0.945494
# [2370]	validation_0-auc:0.999876	validation_1-auc:0.945524
# [2400]	validation_0-auc:0.999887	validation_1-auc:0.945625
# [2430]	validation_0-auc:0.999896	validation_1-auc:0.94561
# [2460]	validation_0-auc:0.999905	validation_1-auc:0.945651
# [2490]	validation_0-auc:0.999911	validation_1-auc:0.945722
# [2520]	validation_0-auc:0.999917	validation_1-auc:0.945698
# [2550]	validation_0-auc:0.999923	validation_1-auc:0.945717
# [2580]	validation_0-auc:0.999928	validation_1-auc:0.945705
# [2610]	validation_0-auc:0.999933	validation_1-auc:0.945665
# [2640]	validation_0-auc:0.999938	validation_1-auc:0.945708
# [2670]	validation_0-auc:0.999943	validation_1-auc:0.945715
# [2700]	validation_0-auc:0.999948	validation_1-auc:0.945728
# [2730]	validation_0-auc:0.999952	validation_1-auc:0.945695
# [2760]	validation_0-auc:0.999956	validation_1-auc:0.945681
# [2790]	validation_0-auc:0.999959	validation_1-auc:0.945724
# [2820]	validation_0-auc:0.999962	validation_1-auc:0.945747
# [2850]	validation_0-auc:0.999964	validation_1-auc:0.945759
# [2880]	validation_0-auc:0.999967	validation_1-auc:0.945807
# [2910]	validation_0-auc:0.999969	validation_1-auc:0.945805
# [2940]	validation_0-auc:0.999972	validation_1-auc:0.945766
# [2970]	validation_0-auc:0.999975	validation_1-auc:0.945833
# [3000]	validation_0-auc:0.999977	validation_1-auc:0.945805
# [3030]	validation_0-auc:0.999979	validation_1-auc:0.945794
# [3060]	validation_0-auc:0.999981	validation_1-auc:0.945822
# [3090]	validation_0-auc:0.999982	validation_1-auc:0.945874
# [3120]	validation_0-auc:0.999983	validation_1-auc:0.945856
# [3150]	validation_0-auc:0.999985	validation_1-auc:0.945864
# [3180]	validation_0-auc:0.999986	validation_1-auc:0.945869
# [3210]	validation_0-auc:0.999987	validation_1-auc:0.945832
# [3240]	validation_0-auc:0.999988	validation_1-auc:0.945893
# [3270]	validation_0-auc:0.999989	validation_1-auc:0.945877
# [3300]	validation_0-auc:0.99999	validation_1-auc:0.945839
# [3330]	validation_0-auc:0.999991	validation_1-auc:0.945865
# [3360]	validation_0-auc:0.999992	validation_1-auc:0.945846
# [3390]	validation_0-auc:0.999993	validation_1-auc:0.945837
# [3420]	validation_0-auc:0.999993	validation_1-auc:0.945874
# [3450]	validation_0-auc:0.999994	validation_1-auc:0.945861
# [3480]	validation_0-auc:0.999994	validation_1-auc:0.945868
# [3510]	validation_0-auc:0.999995	validation_1-auc:0.94591
# [3540]	validation_0-auc:0.999995	validation_1-auc:0.945869
# [3570]	validation_0-auc:0.999995	validation_1-auc:0.945861
# [3600]	validation_0-auc:0.999996	validation_1-auc:0.94587
# [3630]	validation_0-auc:0.999996	validation_1-auc:0.945854
# [3660]	validation_0-auc:0.999996	validation_1-auc:0.945891
# [3690]	validation_0-auc:0.999997	validation_1-auc:0.945847
# [3720]	validation_0-auc:0.999997	validation_1-auc:0.945885
# [3750]	validation_0-auc:0.999997	validation_1-auc:0.945841
# [3780]	validation_0-auc:0.999997	validation_1-auc:0.94589
# [3810]	validation_0-auc:0.999998	validation_1-auc:0.945911
# [3840]	validation_0-auc:0.999998	validation_1-auc:0.945904
# [3870]	validation_0-auc:0.999998	validation_1-auc:0.9459
# [3900]	validation_0-auc:0.999998	validation_1-auc:0.945848
# [3930]	validation_0-auc:0.999998	validation_1-auc:0.945894
# [3960]	validation_0-auc:0.999999	validation_1-auc:0.945892
# [3990]	validation_0-auc:0.999999	validation_1-auc:0.945935
# [4020]	validation_0-auc:0.999999	validation_1-auc:0.945899
# [4050]	validation_0-auc:0.999999	validation_1-auc:0.945926
# [4080]	validation_0-auc:0.999999	validation_1-auc:0.945906
# [4110]	validation_0-auc:0.999999	validation_1-auc:0.945929
# [4140]	validation_0-auc:0.999999	validation_1-auc:0.945942
# [4170]	validation_0-auc:0.999999	validation_1-auc:0.945968
# [4200]	validation_0-auc:0.999999	validation_1-auc:0.945971
# [4230]	validation_0-auc:0.999999	validation_1-auc:0.945996
# [4260]	validation_0-auc:0.999999	validation_1-auc:0.945988
# [4290]	validation_0-auc:0.999999	validation_1-auc:0.945986
# [4320]	validation_0-auc:1	validation_1-auc:0.94599
# [4350]	validation_0-auc:1	validation_1-auc:0.946016
# [4380]	validation_0-auc:1	validation_1-auc:0.946059
# [4410]	validation_0-auc:1	validation_1-auc:0.946057
# [4440]	validation_0-auc:1	validation_1-auc:0.946063
# [4470]	validation_0-auc:1	validation_1-auc:0.946056
# [4500]	validation_0-auc:1	validation_1-auc:0.946063
# [4530]	validation_0-auc:1	validation_1-auc:0.946057
# [4560]	validation_0-auc:1	validation_1-auc:0.946076
# [4590]	validation_0-auc:1	validation_1-auc:0.946079
# [4620]	validation_0-auc:1	validation_1-auc:0.946064
# [4650]	validation_0-auc:1	validation_1-auc:0.946062
# [4680]	validation_0-auc:1	validation_1-auc:0.94607
# [4710]	validation_0-auc:1	validation_1-auc:0.946057
# [4740]	validation_0-auc:1	validation_1-auc:0.94603
# [4770]	validation_0-auc:1	validation_1-auc:0.946019
# [4800]	validation_0-auc:1	validation_1-auc:0.945993
# [4830]	validation_0-auc:1	validation_1-auc:0.946004
# [4860]	validation_0-auc:1	validation_1-auc:0.94598
# [4890]	validation_0-auc:1	validation_1-auc:0.945963
# Stopping. Best iteration:
# [4394]	validation_0-auc:1	validation_1-auc:0.946087
#
# 0.9460870814607542
# End:0.9536104887464999

# %%
resu = pd.read_csv('../input/ieee-fraud-detection/sample_submission.csv')
resu['isFraud'] = y_pred
resu.to_csv('xgb.csv',index=False)
a= pd.DataFrame()
a['train'] = stack_train
a.to_csv('xgb_train.csv',index=False)
